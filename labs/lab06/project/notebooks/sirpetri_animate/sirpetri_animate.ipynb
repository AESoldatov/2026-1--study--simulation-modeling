# %%
using DrWatson
@quickactivate "project"
include(srcdir("SIRPetri.jl"))
using .SIRPetri
using DataFrames, CSV, Plots

# %% [markdown]
# Параметры

# %%
β = 0.3
γ = 0.1
tmax = 100.0

net, u0, states = build_sir_network(β, γ)

group_names = string.(states)  # ["S", "I", "R"]

df_det = simulate_deterministic(net, u0, (0.0, tmax), saveat = 0.2, rates = [β, γ])


anim = @animate for row in eachrow(df_det) # Анимация

    u = [row[col] for col in propertynames(row) if col != :time]


    plot(
        1:length(u),
        u,
        legend = false,
        ylims = (0, 1000),
        xlabel = "Compartment",
        ylabel = "Population",
        title = "SIR dynamics at t = $(round(row.time, digits=2))",
        markersize = 4,
        markerstrokewidth = 0,
        linewidth = 2,
        color = [:blue :red :green],
        marker = :circle,
        linestyle = :solid
    )

    xticks!(1:length(group_names), group_names, rotation = 0)

    plot!(grid = true, gridalpha = 0.3)
end
# Out:
# Animation("C:\\Users\\AESOLD~1\\AppData\\Local\\Temp\\jl_ThG1fy", ["000001.png", "000002.png", "000003.png", "000004.png", "000005.png", "000006.png", "000007.png", "000008.png", "000009.png", "000010.png"  …  "000492.png", "000493.png", "000494.png", "000495.png", "000496.png", "000497.png", "000498.png", "000499.png", "000500.png", "000501.png"])

# %% [markdown]
# Сохранение

# %%
gif(anim, plotsdir("sir_animation.gif"), fps = 15)
println("Анимация сохранена в plots/sir_animation.gif")
# Out:
# Анимация сохранена в plots/sir_animation.gif
# [ Info: Saved animation to C:\Users\AESoldatov\work\study\2026-1\2026-1==study--simulation-modeling\2026-1--study--simulation-modeling\labs\lab06\project\plots\sir_animation.gif
